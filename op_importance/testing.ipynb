# %%
x = ['CO_TranslateShape_circle_35_pts_statav4_m', 'SY_DriftingMean50_min', 'CO_AddNoise_1_even_10_ami_at_10', 'IN_AutoMutualInfoStats_diff_20_gaussian_ami8', 'SC_FluctAnal_2_dfa_50_2_logi_r2_se2', 'MF_CompareAR_1_10_05_stddiff', 'PH_Walker_momentum_5_w_momentumzcross', 'MF_steps_ahead_arma_3_1_6_ac1_6', 'DN_RemovePoints_absclose_05_ac2rat', 'ApEn2_01', 'MF_steps_ahead_ar_2_6_maxdiffrms', 'CO_HistogramAMI_even_2_3', 'MF_steps_ahead_ar_best_6_rmserr_6', 'PH_ForcePotential_sine_10_004_10_std', 'SP_Summaries_welch_rect_fpolysat_rmse', 'AC_nl_036', 'FC_LocalSimple_mean3_stderr', 'AC_nl_112', 'ST_LocalExtrema_n100_diffmaxabsmin', 'MF_StateSpace_n4sid_1_05_1_ac2']

# %%
len(x)
# Out:
# 20

# %%
np.load("reduced.npy").shape
# Out:
# (12, 30)

# %%
np.load("result_mat.npy").shape
# Out:
# (30, 12)

# %%
import numpy as np
import matplotlib.pyplot as plt
average_performance = np.loadtxt("peformance_mat_fullMeanStd_topMeanStd_clusterMeanStd_givenSplit_nonBalanced_new710_average.txt")
complete_performance = np.loadtxt("peformance_mat_fullMeanStd_topMeanStd_clusterMeanStd_givenSplit_nonBalanced_new710_complete.txt")

# %%
plt.figure()
plt.plot((0, 1.5), (0, 1.5), '--', color=np.array((1, 1, 1)) * 0.7)
plt.errorbar(average_performance[:, 4], complete_performance[:, 4],
                                xerr=average_performance[:, 5], yerr=complete_performance[:, 5], fmt='o',
                                color='r', ecolor='r')
# plt.errorbar(complete_performance[:, 0], complete_performance[:, 4],
#                                 xerr=complete_performance[:, 1], yerr=complete_performance[:, 5], fmt='o',
#                                 color='g', ecolor='g')
plt.xlabel('Accuracy of catchaMouse16')
plt.ylabel('Accuracy of complete linkage centroids') # catchaMouse16
# Out:
# Text(0, 0.5, 'Accuracy of complete linkage centroids')

# %%
print(Warning("Hello"))

print(2+2)
# Out:
# Hello
# 4

# %%
import warnings

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
y = np.random.rand(10)
x = np.arange(10)
fig,ax = plt.subplots()
ax.plot(x,y)

# %%
ax.get_yticks()
# Out:
# array([-0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ])
